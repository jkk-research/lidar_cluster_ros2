# %%
import dblane_demo as dbl
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
candidate_pts = dbl.read_data('data/test01.csv')
cluster1 = dbl.Cluster(candidate_points=candidate_pts, eps_min=0.2, eps_max=0.8, ang_threshold_deg=30.0, cluster_num=4)
cluster1.calcuate_clusters()
# cluster1.print_cluster(1)
dbl.plot_data(candidate_pts, fig=fig, ax=ax)
