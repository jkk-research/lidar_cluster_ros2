# %%
import dblane_demo as dbl
import matplotlib.pyplot as plt

candidate_pts = dbl.read_data('data/test01.csv')
points = dbl.find_neighbors(candidate_pts, 0.8)
dbl.plot_data(candidate_pts)

print(len(candidate_pts))
cluster1 = dbl.Cluster([], candidate_pts, 0)
cluster1.add_back(candidate_pts[3], 0)
cluster1.add_back(candidate_pts[4], 0)
cluster1.add_back(candidate_pts[5], 0)
cluster1.next_tail(0.2,0.8)
dbl.plt_cluster(cluster1)
# Out:
# 46
# head: [0.4, 1.6] [0.2, 1]
# tail: [0.7, 3.1] [0.9, 4]

# %%
for i in range(20):
    cluster1.next_tail(0.2,0.8)
dbl.plot_data(candidate_pts)    
dbl.plt_cluster(cluster1)
# Out:
# head: [0.4, 1.6] [0.2, 1]
# tail: [1.6, 9.1] [2.0, 10]
