# %%
import dbscan_demo as dbs

points = dbs.read_data('data/test01.csv')
points = dbs.find_neighbors(points, 0.9)
points = dbs.find_clusters(points, 0.9)
# dbs.print_data(points)
dbs.plot_data(points)
